-- %% [markdown]
-- # [dbo].[FlightTechlogSp]

-- %%
USE [ShearAccAviaV6.0]
GO

-- %%
/****** Object:  StoredProcedure [dbo].[FlightTechlogSp]    Script Date: 5/10/2022 10:55:13 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE Procedure [dbo].[FlightTechlogSp]
@TechlogNo int
AS
BEGIN

If @TechlogNo > 30000
BEGIN
SELECT * From Flight WHERE TechlogNo=@TechlogNo
END

Else
BEGIN
SELECT * From Flight
END

END
GO

-- %% [markdown]
-- # [dbo].[FuelTechlogSp]

-- %%
/****** Object:  StoredProcedure [dbo].[FuelTechlogSp]    Script Date: 5/10/2022 10:55:13 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		Gitata M.M.
-- Create date: 16/10/12
-- Description:	get the techlog for a specific TechLogNo
-- =============================================
CREATE PROCEDURE [dbo].[FuelTechlogSp]

	@TechLogNo INT
	
AS
BEGIN
	-- SET NOCOUNT ON added to prevent extra result sets from
	-- interfering with SELECT statements.
	SET NOCOUNT ON;

    -- Insert statements for procedure here
	SELECT * FROM Fuel WHERE TechLogNo = @TechLogNo
END
GO
